# %%
#print Welcome
print("Welcome")

import sqlite3

#Create a database
conn = sqlite3.connect('Agarwalstvl.db')

#import & print the image
import matplotlib.pyplot as plt 
img = plt.imread("E:\Internship Dec\images.png") 
plt.imshow(img) 
plt.axis('off')
plt.show()

#print Hospital Name & moto

print("\033[1;34;48m Dr. AGARWAL'S EYE HOSPITAL \n FOR EYES LIKE NEW \033[0m")

#password & user and other menu selections
import getpass
password = getpass.getpass(prompt='Enter Your Password:')

hidden_password =''
for char in password:
    hidden_password += '*'

#password = input("Please enter the password: ")
if password == "Test Security":
    print("Password Accepted.")


    #for Database 

    import sqlite3

    #Connecting to the database
    conn = sqlite3.connect('sample4hospital.db')

    #Creating a cursor
    c = conn.cursor()

    #Creating Staff table
    c.execute(""" CREATE TABLE IF NOT EXISTS hospital_staff
                  (staff_id integer PRIMARY KEY,
                   staff_name text NOT NULL,
                   department text NOT NULL);
                   """)

    #Creating Patient table
    c.execute(""" CREATE TABLE IF NOT EXISTS hospital_patient
                  (patient_id integer PRIMARY KEY,
                   patient_name text NOT NULL,
                   age integer NOT NULL,
                   phone_no integer NOT NULL,
                   regestration_date integer NOT NULL,
                   no_of_vist integer NOT NULL,
                   scan text NOT NULL,
                   surgery text NOT NULL,
                   surgery_name text NOT NULL,
                   eye text NOT NULL,
                   surgeon text NOT NULL,
                   ass_by text NOT NULL,
                   aneasthetic text NOT NULL,
                   aneasthetist text NOT NULL);
                   """)
    #Creating Complaint table
    c.execute("""CREATE TABLE IF NOT EXISTS hospital_complaint
                 (complaint_id integer PRIMARY KEY,
                  complaint_name text NOT NULL)
                  """)
    #Creating Administrator table
    c.execute("""CREATE TABLE IF NOT EXISTS hospital_administrator
                 (staff_id integer PRIMARY KEY,
                  staff_name text NOT NULL,
                  department text NOT NULL)
                  """)
    #Creating Coordinator table
    c.execute("""CREATE TABLE IF NOT EXISTS hospital_coordinator
                 (staff_id integer PRIMARY KEY,
                  staff_name text NOT NULL,
                  department text NOT NULL)
                  """)
    #Creating Member table
    c.execute("""CREATE TABLE IF NOT EXISTS hospital_member
                 (staff_id integer PRIMARY KEY,
                  staff_name text NOT NULL,
                  department text NOT NULL)
                  """)
    #Creating Review table
    c.execute("""CREATE TABLE IF NOT EXISTS hospital_review
                 (review_id integer PRIMARY KEY,
                  review_content text NOT NULL,
                  review_sentiment text NOT NULL)
                  """)
    

    #Adding data to the table
    def add_s_data(table_name, staff_id, staff_name, department):
        c.execute(f"INSERT INTO {table_name} VALUES ({staff_id}, '{staff_name}', '{department}')")
        conn.commit()
    def add_p_data(table_name, patient_id, patient_name, age, phone_no, regestration_date, no_of_vist, scan, surgery, surgery_name, eye, surgeon, ass_by, aneasthetic, aneasthetist):
        c.execute(f"INSERT INTO {table_name} VALUES ({patient_id}, '{patient_name}', '{age}', '{phone_no}', '{regestration_date}', '{no_of_vist}', '{scan}', '{surgery}', '{surgery_name}', '{eye}', '{surgeon}', '{ass_by}', '{aneasthetic}', '{aneasthetist}')")
        conn.commit()
    def add_c_data(table_name, complaint_id, complaint_name):
        c.execute(f"INSERT INTO {table_name} VALUES ({complaint_id}, '{complaint_name}')")
        conn.commit()
    def add_a_data(table_name, staff_id, staff_name, department):
        c.execute(f"INSERT INTO {table_name} VALUES ({staff_id}, '{staff_name}', '{department}')")
        conn.commit()
    def add_co_data(table_name, staff_id, staff_name, department):
        c.execute(f"INSERT INTO {table_name} VALUES ({staff_id}, '{staff_name}', '{department}')")
        conn.commit() 
    def add_m_data(table_name, staff_id, staff_name, department):
        c.execute(f"INSERT INTO {table_name} VALUES ({staff_id}, '{staff_name}', '{department}')")
        conn.commit()
    def add_r_data(table_name, review_id, review_content, review_sentiment):
        c.execute(f"INSERT INTO {table_name} VALUES ({review_id}, '{review_content}','{review_sentiment}')")
        conn.commit()
        
    #Editing data in the table
    def edit_s_data(table_name, staff_id, staff_name, department):
        c.execute(f"UPDATE {table_name} SET staff_name = '{staff_name}', department = '{department}' WHERE staff_id = {staff_id}")
        conn.commit()
    def edit_p_data(table_name, patient_id, patient_name, age, phone_no, regestration_date, no_of_vist, scan, surgery, surgery_name, eye, surgeon, ass_by, aneasthetic, aneasthetist):
        c.execute(f"UPDATE {table_name} SET patient_name = '{patient_name}', age = '{age}', phone_no = '{phone_no}', regestration_date = '{regestration_date}', no_of_vist = '{no_of_vist}', scan = '{scan}', surgery = '{surgery}', surgery_name = '{surgery_name}', eye = '{eye}', surgeon = '{surgeon}', ass_by = '{ass_by}', aneasthetic = '{aneasthetic}', aneasthetist = '{aneasthetist}' WHERE patient_id = {patient_id}")
        conn.commit()
    def edit_c_data(table_name, complaint_id, complaint_name):
        c.execute(f"UPDATE {table_name} SET complaint_name = '{complaint_name}'")
        conn.commit()
    def edit_a_data(table_name, staff_id, staff_name, department):
        c.execute(f"UPDATE {table_name} SET staff_name = '{staff_name}', department = '{department}' WHERE staff_id = {staff_id}")
        conn.commit()
    def edit_co_data(table_name, staff_id, staff_name, department):
        c.execute(f"UPDATE {table_name} SET staff_name = '{staff_name}', department = '{department}' WHERE staff_id = {staff_id}")
        conn.commit()
    def edit_m_data(table_name, staff_id, staff_name, department):
        c.execute(f"UPDATE {table_name} SET staff_name = '{staff_name}', department = '{department}' WHERE staff_id = {staff_id}")
        conn.commit()
    def edit_r_data(table_name, review_id, review_content, review_sentiment):
        c.execute(f"UPDATE {table_name} SET review_content = '{review_content}', review_sentiment = '{review_sentiment}'")
        conn.commit()
    
    #Deleting data from the table
    def delete_s_data(table_name, staff_id):
        c.execute(f"DELETE FROM {table_name} WHERE staff_id = {staff_id}")
        conn.commit()
    def delete_p_data(table_name, patient_id):
        c.execute(f"DELETE FROM {table_name} WHERE patient_id = {patient_id}")
        conn.commit()
    def delete_c_data(table_name, complaint_id, complaint_name):
        c.execute(f"DELETE FROM {table_name} WHERE complaint_id = {complaint_name}")
        conn.commit()
    def delete_a_data(table_name, staff_id):
        c.execute(f"DELETE FROM {table_name} WHERE staff_id = {staff_id}")
        conn.commit()
    def delete_co_data(table_name, staff_id):
        c.execute(f"DELETE FROM {table_name} WHERE staff_id = {staff_id}")
        conn.commit()
    def delete_m_data(table_name, staff_id):
        c.execute(f"DELETE FROM {table_name} WHERE staff_id = {staff_id}")
        conn.commit()
    def delete_r_data(table_name, review_id):
        c.execute(f"DELETE FROM {table_name} WHERE review_id = {review_id}")
        conn.commit()

    #Viewing data in the table
    def view_s_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)
    def view_p_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)
    def view_c_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)
    def view_a_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)
    def view_co_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)
    def view_m_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)
    def view_r_data(table_name):
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()
        for row in rows:
            print(row)

    
    user_type = int(input("Please select the user type: \n 1. Coordinator \n 2. Administrator \n 3. Member \n 4. Owner \n Please select the corresponding number: "))
    if user_type == 1:
        print("User type selected.\nCoordinator:\nYou have the authority to add, delete, edit or view Administrator & Member.")
        cord_type = int(input("\n 1. Show Administrator List \n 2. Add Administrator \n 3. Edit Administrator \n 4. Delete Administrator \n 5. Show Member List \n 6. Add Member \n 7. Edit Member \n 8. Detele Member \n Please select the corresponding number: "))   
        
        # for cord_type 
        if cord_type == 1:
            print("\n Showing Administrator List")
            view_a_data('hospital_administrator')
        elif cord_type == 2:
            print("\n Adding new Administrator")
            staff_id = int(input("Enter the Staff ID:"))
            staff_name = input("Enter the Staff name:")
            department = input("Enter the Department:")
            add_a_data('hospital_administrator', staff_id, staff_name, department)
            print("\n NEW ADMINISTRATOR ADDED")
        elif cord_type == 3:
            print("\nEditing Administrator")
            staff_id = int(input("Enter the staff id:"))
            staff_name = input("Enter the staff name:")
            department = input("Enter the department:")
            edit_a_data('hospital_administrator', staff_id, staff_name, department)
        elif cord_type == 4:
            print("\n Deleting Administrator")
            staff_id = int(input("Enter the staff id:"))
            delete_a_data('hospital_administrator', staff_id)
        elif cord_type == 5:
            print(" \n Showing Member List")
            view_m_data('hospital_member')
        elif cord_type == 6:
            print(" \n Adding Member")
            staff_id = int(input("Enter the Staff ID:"))
            staff_name = input("Enter the Staff name:")
            department = input("Enter the Department:")
            add_m_data('hospital_member', staff_id, staff_name, department)
        elif cord_type == 7:
            print(" \n Editing Member")
            staff_id = int(input("Enter the staff id:"))
            staff_name = input("Enter the staff name:")
            department = input("Enter the department:")
            edit_m_data('hospital_member', staff_id, staff_name, department)
        elif cord_type == 8:
            print(" \n Deleting Member")
            staff_id = int(input("Enter the staff id:"))
            delete_m_data('hospital_member', staff_id)
        else:
            print("\n Invalid Input")
            
    elif user_type == 2:
        print("User type selected.\nAdministrator:\nYou have the authority to edit the employees (Name, code and department) or add, delete or edit complaints.")
        admi_type = int(input("\n 1. Show Employee List \n 2. Adding Employee \n 3. Editing Employee \n 4. Deleting Employee \n 5. Show Complaints List \n 6. Add Complaints \n 7. Edit Complaints \n 8. Delete Complaints \n 9. Show Review List \n 10. Add Review \n 11. Edit Review \n 12. Delete Review \n 13. Review Summary \n 14. Find a Solution for Complaint \n Please select the correspoinding number: "))
        
        # for admi_type
        if admi_type == 1:
            print("\n Showing Employee List")
            view_s_data('hospital_staff')
        elif admi_type == 2:
            print("\n Adding Employee")
            staff_id = int(input("Enter the Staff ID:"))
            staff_name = input("Enter the Staff name:")
            department = input("Enter the Department:")
            add_s_data('hospital_staff', staff_id, staff_name, department)
        elif admi_type == 3:
            print("\n Editing Employee")
            staff_id = int(input("Enter the staff id:"))
            staff_name = input("Enter the staff name:")
            department = input("Enter the department:")
            edit_s_data('hospital_staff', staff_id, staff_name, department)
        elif admi_type == 4:
            print("\n Deleting Employee")
            staff_id = int(input("Enter the staff id:"))
            delete_s_data('hospital_staff', staff_id)
        elif admi_type == 5:
            print("\n Showing Complaint List")
            view_c_data('hospital_complaint')
        elif admi_type == 6:
            print("\n Adding Complaint") 
            complaint_id = int(input("Enter the Complaint ID:"))
            complaint_name = input("Enter the Complaint name:")            
            add_c_data('hospital_complaint', complaint_id, complaint_name)
        elif admi_type == 7:
            print(" \n Editing Complaint")
            complaint_id = int(input("Enter the Complaint ID:"))
            complaint_name = input("Enter the Complaint name:")            
            edit_c_data('hospital_complaint', complaint_id, complaint_name)
        elif admi_type == 8:
            print(" \n Deleting Complaint")
            complaint_id = int(input("Enter the Complaint ID:"))           
            delete_c_data('hospital_complaint', complaint_id)
        elif admi_type == 9:
            print("\n Showing Review List")
            view_r_data('hospital_review')
        elif admi_type == 10:
            print("\n Adding Review") 
            review_id = int(input("Enter the Review ID:"))
            review_content = input("Enter the Review Content:")     
            from textblob import TextBlob
            sentiment = TextBlob(review_content).sentiment.polarity
            if sentiment > 0:
                review_sentiment = "positive"
            elif sentiment < 0:
                review_sentiment = "negative"
            else:
                review_sentiment = "neutral"
                print("Review Sentiment:", review_sentiment)
            add_r_data('hospital_review', review_id, review_content,review_sentiment)
        elif admi_type == 11:
            print(" \n Editing Review")
            review_id = int(input("Enter the Review ID:"))
            review_content = input("Enter the Review Content:")  
            from textblob import TextBlob
            sentiment = TextBlob(review_content).sentiment.polarity
            if sentiment > 0:
                review_sentiment = "positive"
            elif sentiment < 0:
                review_sentiment = "negative"
            else:
                review_sentiment = "neutral"
                print("Review Sentiment:", review_sentiment)
            edit_r_data('hospital_review', review_id, review_content,review_sentiment)
        elif admi_type == 12:
            print(" \n Deleting Review")
            review_id = int(input("Enter the Review ID:"))           
            delete_r_data('hospital_review', review_id)
        elif admi_type == 13:
            print("\n Review Summary")
            import sqlite3

            def fetch_data(table_name):
                conn = sqlite3.connect('sample4hospital.db')
                c = conn.cursor()
                c.execute(f"SELECT * FROM {table_name}")
                data = c.fetchall()
                conn.close()
                return data

            reviews = fetch_data('hospital_review')
            num_reviews = len(reviews)
            num_pos = sum(1 for r in reviews if r[2] == 'positive')
            num_neg = sum(1 for r in reviews if r[2] == 'negative')
            num_neu = num_reviews - num_pos - num_neg
            if num_reviews > 0:
                pos_percent = (num_pos / num_reviews) * 100
                neg_percent = (num_neg / num_reviews) * 100
                neu_percent = (num_neu / num_reviews) * 100
                print(f"Positive reviews: {pos_percent:.2f}%")
                print(f"Negative reviews: {neg_percent:.2f}%")
                print(f"Neutral reviews: {neu_percent:.2f}%")
            else:
                 print("No reviews found.")
        elif admi_type == 14:
            import pandas as pd
            from sklearn.feature_extraction.text import TfidfVectorizer
            from sklearn.metrics.pairwise import cosine_similarity
            from tkinter import *

            # Load complaints and remedies from CSV file
            data = pd.read_csv("C:/Users/Sohan/complaints_new.csv")

            # Vectorize complaints using TF-IDF vectorizer
            vectorizer = TfidfVectorizer()
            complaint_vectors = vectorizer.fit_transform(data['complaint'])

            # Compute cosine similarity matrix between complaints
            cosine_similarities = cosine_similarity(complaint_vectors)

            # Define a function to get the top k most similar complaints to a given complaint
            def get_similar_complaints(complaint, k=2):
                # Vectorize the input complaint
                complaint_vector = vectorizer.transform([complaint])
    
                # Compute cosine similarities between the input complaint and all other complaints
                similarities = cosine_similarity(complaint_vector, complaint_vectors)
    
                # Get the indices of the top k most similar complaints
                indices = similarities.argsort()[0][-k:][::-1]
    
                # Return the top k most similar complaints and their remedies
                return data.iloc[indices][['complaint', 'remedy']]

            # Define a function to recommend remedies for an input complaint
            def recommend():
                # Get the input complaint from the entry box
                complaint = entry.get()
    
                # Get the top 5 most similar complaints and their remedies
                similar_complaints = get_similar_complaints(complaint)
    
                # Display the recommended remedies in the results label
                result_label.config(text="\n".join(similar_complaints['remedy'].tolist()))

            # Create a GUI using tkinter
            root = Tk()
            root.title("Eye Hospital Complaint Recommender")

            entry_label = Label(root, text="Enter your complaint:")
            entry_label.pack()

            entry = Entry(root, width=50)
            entry.pack()

            button = Button(root, text="Recommend Remedies", command=recommend)
            button.pack()

            result_label = Label(root, text="")
            result_label.pack()

            root.mainloop()

        else:
            print("\n Invalid Input")
            
    elif user_type == 3:
        print("User type selected.\nMember:\nYou have the authority to add, delete or edit the patients.")
        mem_type = int(input("\n 1. Show Patitents List \n 2. Add Patients \n 3. Edit Patients \n 4. Delete Patients \n Please select the Corresponding number: "))

        # for mem_type
        if mem_type == 1:
            print("\n Showing Patitent List")
            view_p_data('hospital_patient')
        elif mem_type == 2:
            print("\n Adding Patitent")
            patient_id = int(input("Enter the Patient ID:"))
            patient_name = input("Enter the Patient Name:")
            age = input("Enter the Age:")
            phone_no = input("Enter the Phone no.:")
            regestration_date = input("Enter the Regestration Date:")
            no_of_vist = input("Enter the No. of Vist:")
            scan = input("Enter the Scans:")
            surgery = input("Enter the Surgery(Yes/No):")
            surgery_name = input("Enter the Surgery Name:")
            eye = input("Enter the Eye:")
            surgeon = input("Enter the Surgeon:")
            ass_by = input("Enter the Assisted Surgeon:")
            aneasthetic = input("Enter the Aneasthetic:")
            aneasthetist = input("Enter the Aneasthetist:")    
            add_p_data('hospital_patient', patient_id, patient_name, age, phone_no, regestration_date, no_of_vist, scan, surgery, surgery_name, eye, surgeon, ass_by, aneasthetic, aneasthetist)
        elif mem_type == 3:
            print("\n Editing Patient")
            patient_id = int(input("Enter the patient id:"))
            patient_name = input("Enter the patient name:")
            age = input("Enter the Age:")
            phone_no = input("Enter the Phone no.:")
            regestration_date = input("Enter the Regestration Date:")
            no_of_vist = input("Enter the No. of Vist:")
            scan = input("Enter the Scans:")
            surgery = input("Enter the Surgery(Yes/No):")
            surgery_name = input("Enter the Surgery Name:")
            eye = input("Enter the Eye:")
            surgeon = input("Enter the Surgeon:")
            ass_by = input("Enter the Assisted Surgeon:")
            aneasthetic = input("Enter the Aneasthetic:")
            aneasthetist = input("Enter the Aneasthetist:")
            edit_p_data('hospital_patient', patient_id, patient_name, age, phone_no, regestration_date, no_of_vist, scan, surgery, surgery_name, eye, surgeon, ass_by, aneasthetic, aneasthetist)
        elif mem_type == 4:
            print("\n Deleting Patiet")
            patient_id = int(input("Enter the patient id:"))
            delete_p_data('hospital_patient', patient_id)
        else:
            print("\n Invalid Input")
        
    elif user_type == 4:
        own_type = int(input("\n 1. Adding Coordinator \n 2. Editing Coordinator \n 3. Deleting Coordinator \n 4. Show Coordinator List \n 5. Code details \n Please select the corresponding number: "))
        
        #for own_type
        if own_type == 1:
            print("\n Adding Coordinator")
            staff_id = int(input("Enter the Staff ID:"))
            staff_name = input("Enter the Staff name:")
            department = input("Enter the Department:")
            add_co_data('hospital_coordinator', staff_id, staff_name, department)
        elif own_type == 2:
            print("\n Editing Coordinator")
            staff_id = int(input("Enter the staff id:"))
            staff_name = input("Enter the staff name:")
            department = input("Enter the department:")
            edit_co_data('hospital_coordinator', staff_id, staff_name, department)
        elif own_type == 3:
            print("\n Deleting Coordinator")
            staff_id = int(input("Enter the staff id:"))
            delete_co_data('hospital_coordinator', staff_id)
        elif own_type == 4:
            print("\n Showing Coordinator List")
            view_co_data('hospital_coordinator')
        elif own_type == 5:
            print("User type selected.\n Owner: \n You have the authority to edit the page. \n Note: ONLY PAGE CREATOR SOHAN CAN EDIT THE PAGE \n beacuse it is HIGHLY SECURED. THERE ARE CHANCES FOR THE SYSTEM TO CRASH. \n Please start editing the code.")  
            password = input("Please enter the password: ")
            if password == "Sohan":
                print("\n Password Accepted.")
                cod_type = int(input("\n 1. Show Code \n 2. Edit Code \n Enter your Choice: "))
                
                #for cod_type
                if cod_type == 1:
                    print("\n Showing Code")
                elif cod_type == 2:
                    print("\n Editing Code")
                else:
                    print("\n Invalid Choice")
            else:
                print("\n Wrong Password")
        else:
            print("\n Invalid Input")
    else:
        print("Error: Invalid user type.")
else:
    print("Error: Incorrect password.")
# Out:
# Welcome
#  Dr. AGARWAL'S EYE HOSPITAL
#  FOR EYES LIKE NEW
# Enter Your Password:········
# Password Accepted.
# Please select the user type:
#  1. Coordinator
#  2. Administrator
#  3. Member
#  4. Owner
#  Please select the corresponding number: 2
# User type selected.
# Administrator:
# You have the authority to edit the employees (Name, code and department) or add, delete or edit complaints.
#
#  1. Show Employee List
#  2. Adding Employee
#  3. Editing Employee
#  4. Deleting Employee
#  5. Show Complaints List
#  6. Add Complaints
#  7. Edit Complaints
#  8. Delete Complaints
#  9. Show Review List
#  10. Add Review
#  11. Edit Review
#  12. Delete Review
#  13. Review Summary
#  14. Find a Solution for Complaint
#  Please select the correspoinding number: 14
